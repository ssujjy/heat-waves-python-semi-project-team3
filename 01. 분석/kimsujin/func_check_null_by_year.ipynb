# %%
import pandas as pd

# 연도별로 값이 없는 나라 확인하는 함수
# def func_check_null_by_year(df):
na_contry_year = {}
for i in range(1990,2021):
    # na_china_cnt = 0
    # na_china = 0
    temp_data = pd.read_csv(f'Data/rank/{i}.csv')
    na_contry = temp_data[temp_data[str(i)]==0]
    # top_contry = temp_data[temp_data[str(i)]>0]
    # print("결측치가 있는 데이터 : ")
    # print(f"갯수 : {na_contry.count()}")
    # print(na_contry['국가별'])  # 값이 없는 나라 확인.
    na_contry_year[i] = pd.Series(na_contry['국가별'])
    # count_china = sum(['중국' in series.values for series in na_contry_year.values()])
    # if na_contry['국가별'] == "중국" : na_china +=1
    # if na_contry['국가별'] in "중국" : na_china += 1
   
    # print(na_china)    
    # print("=================================")
    # print("결측치가 없는 데이터 : ")
    # print(f"갯수 : {top_contry.count()}")
    # print(top_contry.head(10))  # 값이 있는 나라 확인.

# %%
na_contry_year
# Out:
# {1990: 53    이스라엘
#  54      이란
#  55      중국
#  56      페루
#  57      인도
#  Name: 국가별, dtype: object,
#  1991: 51          중국
#  52          인도
#  53          이란
#  54        이스라엘
#  55     사우디아라비아
#  56          페루
#  57    남아프리카공화국
#  Name: 국가별, dtype: object,
#  1992: 51          페루
#  52          중국
#  53          인도
#  54          이란
#  55        이스라엘
#  56     사우디아라비아
#  57    남아프리카공화국
#  Name: 국가별, dtype: object,
#  1993: 51          페루
#  52          중국
#  53          인도
#  54          이란
#  55        이스라엘
#  56     사우디아라비아
#  57    남아프리카공화국
#  Name: 국가별, dtype: object,
#  1994: 56       이스라엘
#  57    사우디아라비아
#  Name: 국가별, dtype: object,
#  1995: 50          페루
#  51          중국
#  52          인도
#  53       인도네시아
#  54          이란
#  55        이스라엘
#  56     사우디아라비아
#  57    남아프리카공화국
#  Name: 국가별, dtype: object,
#  1996: 51          페루
#  52          중국
#  53          인도
#  54       인도네시아
#  55          이란
#  56     사우디아라비아
#  57    남아프리카공화국
#  Name: 국가별, dtype: object,
# ...

# %%
# 찾고자 하는 국가
target_country = '중국'

# 카운트 변수 초기화
count = 0

for key, value in na_contry_year.items():
    # 리스트에 target_country가 있으면 카운트 증가
    if target_country in value.values:
        count += 1


count









    # df = pd.DataFrame(value)

    # # 확인할 국가 리스트
    # countries_to_check = ['중국']

    # # 중국이 빠진 년도의 갯수
    # count_china_na = 0
    # count_india_na = 0

    # # 데이터프레임에 국가가 포함되어 있는지 확인
    # for country in countries_to_check:
    #     # if country in df['국가별'].values:
    #         # print(f"{country}가 데이터셋에 포함되어 있습니다.")
    #         count_china_na += 1
    #     # else:
    #         # print(f"{country}가 데이터셋에 포함되어 있지 않습니다.")
    #         # count_india_na += 1

    # # print(key, "\n", value)
    # # '중국'이 포함된 경우의 수를 계산
    # # count_china = sum(['중국' in series.values for series in value.values()])
# Out:
# 26

# %%
2021-1990
# Out:
# 31
