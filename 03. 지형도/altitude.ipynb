# %%
import pandas as pd

data = pd.read_csv("data/국토교통부 국토지리정보원_항공사진_수치표고기본메타데이터_20231107.csv", encoding="euc-kr")
code_data = pd.read_csv("data/국토교통부 국토지리정보원_수치지도_코드_20231107.csv", encoding="euc-kr")

# %%
code_data
# Out:
#    코드종류  코드            코드명  기타정보
# 0   use  00  교통관리(ITS/TMS)   NaN
# 1   use  01           교통사고   NaN
# 2   use  02       교통안전시설관리   NaN
# 3   use  06        도로관리/유지   NaN
# 4   use  07           도로설계   NaN
# ..  ...  ..            ...   ...
# 59  lyr  H0             주기   NaN
# 60  ord  10         행정구역주문   NaN
# 61  ord  20           도엽주문   NaN
# 62  ord  30         공간질의주문   NaN
# 63  ord  40        사용자지정주문   NaN
#
# [64 rows x 4 columns]

# %%
data.tail()
# Out:
#              배포부서전화 품질적용대상        평가기준문서 적용대상자료명칭 공간표현방식    행정구역명 행정구역코드  \
# 23185  031-210-2600    DEM  항공레이저측량 작업규정     격자자료    래스터   경기도양평군  41830
# 23186  031-210-2600    DEM  항공레이저측량 작업규정     격자자료    래스터   경기도양평군  41830
# 23187  031-210-2600    DEM  항공레이저측량 작업규정     격자자료    래스터  경기도남양주시  41360
# 23188  031-210-2600    DEM  항공레이저측량 작업규정     격자자료    래스터   경기도광주시  41610
# 23189  031-210-2600    DEM  항공레이저측량 작업규정     격자자료    래스터   경기도광주시  41610
#
#          책임기관명  책임부서명        책임부서전화  ... 책임부서우편번호    메타데이터작성일 메타데이터버전 배포포맷명칭  \
# 23185  국토지리정보원  공간영상과  031-210-2675  ...  443-772  2009-09-01     제1판    NIX
# 23186  국토지리정보원  공간영상과  031-210-2675  ...  443-772  2009-09-01     제1판    NIX
# 23187  국토지리정보원  공간영상과  031-210-2675  ...  443-772  2009-09-01     제1판    NIX
# 23188  국토지리정보원  공간영상과  031-210-2675  ...  443-772  2009-09-01     제1판    NIX
# 23189  국토지리정보원  공간영상과  031-210-2675  ...  443-772  2009-09-01     제1판    NIX
#
#       배포포맷버전    배포기관명  배포부서명       사업지구코드  도엽번호5000   언어
# ...
